# %%
import xarray as xr
# Out:
# /home/m/matthewwright/nobackups/anaconda3/envs/initial-analysis/lib/python3.10/site-packages/xarray/backends/cfgrib_.py:29: UserWarning: Failed to load cfgrib - most likely there is a problem accessing the ecCodes library. Try `import cfgrib` to get the full error message
#   warnings.warn(

# %%
str = "/network/group/aopp/predict/AWH024_COOPERNATH_IFS/IFS/IFS-Zambia/constants/lsm.nc"

# %%
file = xr.load_dataset("/network/group/aopp/predict/AWH024_COOPERNATH_IFS/IFS/IFS-Zambia/constants/lsm_orig.nc")
file.to_netcdf("/network/group/aopp/predict/AWH024_COOPERNATH_IFS/IFS/IFS-Zambia/constants/lsm_orig.nc")
file = file.rename({"LSM": "lsm"})
file.to_netcdf(str)
